# %%
# Variable;

# %%
a="nikhilupadhyay"

# %%
print(a)
# Out:
# nikhilupadhyay

# %%
#Rule to create varible name:
#Rule1: Variable name never contain special character '!"#$%&\'()*+,-./:;<=>?@[\\]^`{|}~'
#Rule2: Variable name never start with a number
#Rule3: A variable name must be readable, easy to understand, Related to work

# %%
1ab=10
# Out:
#   Cell In[3], line 1
#     1ab=10
#     ^
# SyntaxError: invalid decimal literal

# %%
#If this no. is come in between the variable name ex= a1bc this is correct
a1bc=10

# %%
print(a1bc)
# Out:
# 10

# %%
ram_gopal_verma=10

# %%
ram_gopal_verma_age=27

# %%
KrishnaKumar=10           #pascal case (Every word starts with a capital letter  ,No space, No underscore)   EX=MyVariableName
krishnaKumarAge=28        #camel case  (First word is small, Next word start with capital letter, No space, nNo underscore)  EX=myVariableName
krishna_kumar_weight=70   #snake case  (All letters are small, Words separated by underscore(_))  EX=my_variable_name
("krishnaKumarAge")       #Inside double quotes, everything becomes plain text and loses its original meaning, except escape characters and formatting.
                          #keyword become string Variables  : Keywords (if, for, while)  : Operators (+ - * /)  : Numbers (calculation ke liye)
# Out:
# 'krishnaKumarAge'
