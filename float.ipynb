# %%
#float
#float contructor is float()
#float is literal is 0.0
#float contain 0,1,3,4,5,6,7,8,9..

# %%
a= float

# %%
a=float()
print(a)
print(type(a))
# Out:
# 0.0
# <class 'float'>

# %%
a=0.0
print(a)
print(type(a))
# Out:
# 0.0
# <class 'float'>

# %%
d="3e101"
print(d)
print(type(d))
# Out:
# 3e101
# <class 'str'>

# %%
2*10.0**10
# Out:
# 20000000000.0
