# %%
#String
#String constructor is str()
#String literal is '',"","""""",''''''
#String support indexing
#String support slicing
#String support concatination
#String is immutable of hashable datatype'
#String have various method

# %%
a= str()   #using constructor created a empty string
a
# Out:
# ''

# %%
print("hellowrolld")
# Out:
# hellowrolld

# %%
"hellowordl"
# Out:
# 'hellowordl'

# %%
print("This is krishna")
'helloworld'
# Out:
# This is krishna
# 'helloworld'

# %%
"This is krishna"
'helloworld'
# Out:
# 'helloworld'

# %%
# using literal create empty string 
b=''
print(type (b))
b
# Out:
# <class 'str'>
# ''

# %%
c=""
print(type(c))
c
# Out:
# <class 'str'>
# ''

# %%
d=""""""
print(type(d))
d
# Out:
# <class 'str'>
# ''

# %%
e=''''''
print(type(e))
e
# Out:
# <class 'str'>
# ''

# %%
#String support indexing

# %%
print("this is nikhil")
# Out:
# this is nikhil

# %%
a="Nikhil"
print(a)
print(type(a))
# Out:
# Nikhil
# <class 'str'>

# %%
c="""NIkhil"""
print(c)
print(type(c))
# Out:
# NIkhil
# <class 'str'>

# %%
d='''Nikhil'''
print(d)
print(type(d))
# Out:
# Nikhil
# <class 'str'>

# %%
print("this is Nikhil upadhyay")
print('this is Nikhil upadhyay')
# Out:
# this is Nikhil upadhyay
# this is Nikhil upadhyay

# %%
print("""this is 
Nikhil 
upadhyay""")
print('''this is Nikhil upadhyay''')
# Out:
# this is
# Nikhil upadhyay
# this is Nikhil upadhyay
